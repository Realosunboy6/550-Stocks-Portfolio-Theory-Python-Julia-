# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# Define sectors with stock symbols
sectors = {
    "Communication Services": ["LYV", "GOOG", "META", "DIS", "NFLX", "IAC", "T", "VZ", "TMUS", "CABO", "NWSA", "TTWO", "EA", "NXST", "FOX", "WBD", "ROKU", "CHTR", "OMC", "PUBGY", "ZG", "LBRDK", "FWONA", "SIRI", "SPOT", "TCEHY", "CCOI", "PINS", "SNAP", "BIDU", "NTES", "WB", "SE", "BILI", "IQ", "HUYA", "DOYU", "TME", "WPP", "LBTYA", "ZM", "VOD", "RCI", "CMCSA", "LUMN", "TEF", "AMX", "KDDIY", "SKM", "NTTYY"],

    "Consumer Discretionary": ["AMZN", "TSLA", "HD", "MCD", "NKE", "LOW", "SBUX", "TJX", "TGT", "BKNG", "GM", "F", "ROST", "MAR", "LVS", "ORLY", "YUM", "EBAY", "AZO", "DHI", "LEN", "RCL", "HLT", "CMG", "NVR", "DRI", "ULTA", "DG", "KMX", "BBY", "ETSY", "HAS", "GRMN", "MGM", "WHR", "TPR", "RL", "GPC", "AAP", "WSM", "BURL", "FND", "PLNT", "PTON", "CHWY", "POOL", "CZR", "WYNN", "PENN", "VFC"],

    "Consumer Staples": ["PG", "KO", "PEP", "WMT", "PM", "MO", "COST", "MDLZ", "DEO", "UL", "CL", "KHC", "KMB", "GIS", "STZ", "ADM", "MNST", "SYY", "CASY", "EL", "TAP", "CPB", "CAG", "HSY", "TSN", "PFGC", "MKC", "CHD", "KDP", "CLX", "LW", "HRL", "SJM", "BG", "TSCO", "SFM", "KR", "DAR", "SAM", "POST", "INGR", "FDP", "FIZZ", "THS", "HAIN", "FLO", "COTY", "USFD", "UNFI", "ACI"],

    "Energy": ["XOM", "CVX", "SHEL", "BP", "TTE", "EQT", "COP", "EQNR", "ENB", "NOV", "EOG", "PBR", "KMI", "PSX", "VLO", "MPC", "WMB", "SU", "OXY", "WHD", "TRP", "TRGP", "EC", "CTRA", "APA", "FANG", "CHRD", "DVN", "CNQ", "CVE", "SLB", "E", "LNG", "OVV", "AR", "RRC", "HAL", "BKR", "SM", "MTDR", "PAA", "DINO", "MUR", "NOG", "OKE", "HP", "FTI", "NBR", "RES", "PTEN"],

    "Financials": ["JPM", "BAC", "WFC", "C", "CFG", "AJG", "AXP", "BK", "BLK", "SCHW", "USB", "PNC", "TFC", "COF", "STT", "MMC", "CB", "AIG", "MET", "PRU", "ALL", "TRV", "AFL", "LNC", "PFG", "AMP", "CME", "ICE", "SPGI", "MCO", "NDAQ", "FDS", "MSCI", "V", "MA", "PYPL", "AON", "BEN", "MS", "LPLA", "WU", "EQH", "SYF", "ALLY", "CACC", "GS", "KEY", "RF", "FITB", "HBAN"],

    "Health Care": ["JNJ", "UNH", "PFE", "ABBV", "LLY", "MRK", "TMO", "ABT", "DHR", "BMY", "AMGN", "MDT", "GILD", "CVS", "ISRG", "CNC", "ELV", "SYK", "ZTS", "REGN", "VRTX", "THC", "BSX", "BDX", "ILMN", "BIIB", "EW", "ALGN", "IQV", "MCK", "CI", "NVO", "CAH", "HSIC", "XRAY", "HOLX", "RMD", "STE", "TFX", "HCA", "LH", "DGX", "A", "MTD", "TECH", "BIO", "IDXX", "DVA", "UHS", "HUM"],
    
    "Industrials": ["HON", "UNP", "UPS", "RTX", "CAT", "BA", "DE", "GE", "MMM", "LMT", "FDX", "NOC", "GD", "EMR", "ITW", "ETN", "CSX", "WM", "CMI", "WAB", "JCI", "LHX", "GWW", "PH", "ROP", "TT", "DAL", "AAL", "UAL", "SWK", "FAST", "EXPD", "RSG", "EFX", "CTAS", "XYL", "IR", "MAS", "PNR", "TXT", "ROL", "SNA", "URI", "JBHT", "ALLE", "AOS", "FLS", "DOV", "PWR", "HII"],

    "Information Technology": ["VRSN", "AAPL", "MSFT", "NVDA", "AVGO", "ORCL", "CSCO", "ACN", "ADBE", "TXN", "IBM", "CRM", "AMD", "INTC", "QCOM", "AMAT", "INTU", "ADI", "MU", "LRCX", "NOW", "FIS", "TYL", "GPN", "PAYX", "ADP", "CTSH", "CDNS", "SNPS", "KLAC", "MCHP", "NXPI", "ADSK", "FTNT", "PANW", "DXC", "HPQ", "KEYS", "TEL", "ZBRA", "GLW", "STX", "WDAY", "AKAM", "SWKS", "MPWR", "ON", "APH", "AVT", "BR"],

    "Materials":  ["LIN", "BHP", "SHW", "RIO", "APD", "ECL", "NEM", "FCX", "DD", "VMC", "MLM", "CTVA", "LYB", "PPG", "DOW", "NUE", "IFF", "ALB", "EMN", "MOS", "CE", "FMC", "AVY", "CF", "AA", "IP", "PKG", "SEE", "BALL", "CC", "HUN", "RS", "STLD", "TECK", "ATI", "CMC", "SLGN", "CLF", "BCPC", "RPM", "OLN", "MTX", "KWR", "FUL", "ASH", "EXP", "NX", "OC", "SQM", "CBT"],

    "Real Estate": ["PLD", "AMT", "EQIX", "SPG", "PSA", "CCI", "WELL", "O", "DLR", "EXR", "AVB", "EQR", "ESS", "VTR", "CUBE", "MAA", "INVH", "UDR", "SUI", "CPT", "WY", "KIM", "FRT", "REG", "IRM", "SLG", "HIW", "HST", "VNO", "NNN", "BRX", "LXP", "DEA", "FR", "STAG", "EGP", "PDM", "OHI", "MPW", "NHI", "SBRA", "LTC", "HR", "DOC", "GMRE", "DEI", "BXP", "REXR", "ADC", "ARE"],
    
    "Utilities": ["NEE", "SO", "DUK", "D", "AEP", "EXC", "SRE", "XEL", "PEG", "ED", "WEC", "ES", "EIX", "DTE", "PPL", "FE", "MGEE", "AEE", "CMS", "ATO", "NI", "CNP", "EVRG", "LNT", "PNW", "AES", "NRG", "VST", "GNE", "BKH", "IDA", "OGE", "POR", "SWX", "UGI", "AVA", "NWE", "OTTR", "NWN", "ORA", "CWCO", "YORW", "AWR", "MSEX", "WTRG", "ARTNA", "AWK", "CWT", "DNP", "HE"]
}

# Define date range
start_date = "2021-01-01"
end_date = "2026-02-19"

# Loop through each sector and fetch stock data
for sector, tickers in sectors.items():
    sector_data = pd.DataFrame()

    for ticker in tickers:
        try:
            print(f"Fetching {ticker} in {sector} sector...")
            df = yf.Ticker(ticker).history(start=start_date, end=end_date, interval="1d")

            if not df.empty:
                df['Ticker'] = ticker  # Add ticker column
                df['Sector'] = sector  # Add sector column
                sector_data = pd.concat([sector_data, df])

        except Exception as e:
            print(f"⚠️ Failed to fetch data for {ticker}: {e}")

    # Save sector data to CSV file
    csv_filename = f"{sector.replace(' ', '_')}.csv"
    sector_data.to_csv(csv_filename, index=True)
    print(f"✅ Data for {sector} saved to {csv_filename}")

print("🚀 Data collection complete for all sectors!")
# Out:
# Fetching LYV in Communication Services sector...
# Fetching GOOG in Communication Services sector...
# Fetching META in Communication Services sector...
# Fetching DIS in Communication Services sector...
# Fetching NFLX in Communication Services sector...
# Fetching IAC in Communication Services sector...
# Fetching T in Communication Services sector...
# Fetching VZ in Communication Services sector...
# Fetching TMUS in Communication Services sector...
# Fetching CABO in Communication Services sector...
# Fetching NWSA in Communication Services sector...
# Fetching TTWO in Communication Services sector...
# Fetching EA in Communication Services sector...
# Fetching NXST in Communication Services sector...
# Fetching FOX in Communication Services sector...
# Fetching WBD in Communication Services sector...
# Fetching ROKU in Communication Services sector...
# Fetching CHTR in Communication Services sector...
# Fetching OMC in Communication Services sector...
# ...

# %%
import pandas as pd
import yfinance as yf
import time

# 1. Load the original file that you have on your computer
print("Loading nasdaq-listed.csv...")
df = pd.read_csv('nasdaq-listed.csv').dropna()

# 2. Filter out non-stock assets and categorize into 11 sectors
print("Filtering non-stock assets and assigning sectors...")

exclude_keywords = [
    r'ETF', r'Warrant', r'Right', r'Unit', r'Preferred', 
    r'Depositary', r'Depository', r'ADR', r'ADS', r'Note', r'Bond', 
    r'Bull \dX', r'Bear \dX', r'Daily ETF', r'Index', r'Trust', r'Debt', 
    r'Receipt', r'Fund', r'Portfolio', r'TEST STOCK', r'Test Stock'
]
mask = df['Security Name'].str.contains('|'.join(exclude_keywords), case=False, na=False)
stocks_only = df[~mask].copy()

# Sector mapping based on company names
sector_mapping = {
    'Health Care': r'Bio|Pharma|Therap|Medical|Health|Life Science|Clinic|Oncology|Genetic|Diagnostic|Medicine|Neuro|Immuno|Vaccine|Care|Geno|Surge|Cardio|Dental',
    'Utilities': r'Utility|Utilities|Water|Electric|Light|Power',
    'Materials': r'Gold|Silver|Mining|Material|Steel|Copper|Chemical|Lithium|Metal|Mineral|Plastic|Packaging|Paper',
    'Real Estate': r'Real Estate|REIT|Property|Properties|Home|Realty|Estate|Housing|Apartment',
    'Energy': r'Energy|Oil|Gas|Petroleum|Resource|Solar|Fuel|Midstream|Drilling|Pipeline|Clean|Renew|Wind|Carbon',
    'Information Technology': r'Tech|Software|Cyber|Network|Computing|Semiconductor|Micro|AI|Data|System|Cloud|Digital|Info|IT|Solution|Opto|Device|Instrument|Electronic|Science|Innovat|Intelligen',
    'Communication Services': r'Media|Communication|Telecom|Wireless|Broadcast|Interactive|Cable|Internet|Publishing|Satellite|Radio|Television|Social',
    'Industrials': r'Airline|Freight|Logistic|Manufacturing|Aerospace|Defense|Transport|Machinery|Aviation|Industrial|Marine|Shipping|Equipment|Building|Construct|Aero|Vehicle|Engine',
    'Consumer Staples': r'Food|Beverage|Farm|Grocery|Nutrition|Agri|Brew|Supermarket|Drink|Meat',
    'Consumer Discretionary': r'Auto|Entertain|Leisure|Retail|Apparel|Brand|Hospitality|Hotel|Resort|Motor|Restaurant|Education|Consumer|Gaming|Sport|Tour|Fashion|Beauty',
    'Financials': r'Bank|Bancorp|Financial|Trust|Capital|Holding|Insurance|Equity|Fund|Credit|Mortgage|Acquisition|Invest|Partner|Wealth|Bancshares|L.P.|Corp|Group|Inc|Company|Ltd'
}

stocks_only['Sector'] = 'Financials' 
for sector_name, pattern in sector_mapping.items():
    s_mask = stocks_only['Security Name'].str.contains(pattern, case=False, na=False)
    stocks_only.loc[s_mask, 'Sector'] = sector_name

explicit_map = {
    'AAPL': 'Information Technology', 'MSFT': 'Information Technology', 'GOOG': 'Communication Services',
    'GOOGL': 'Communication Services', 'AMZN': 'Consumer Discretionary', 'TSLA': 'Consumer Discretionary',
    'META': 'Communication Services', 'NVDA': 'Information Technology', 'NFLX': 'Communication Services',
    'PEP': 'Consumer Staples', 'COST': 'Consumer Staples', 'CSCO': 'Information Technology'
}
for sym, sec in explicit_map.items():
    if sym in stocks_only['Symbol'].values:
        stocks_only.loc[stocks_only['Symbol'] == sym, 'Sector'] = sec

tickers = stocks_only['Symbol'].tolist()

# 3. Download data in batches to avoid rate limits
print(f"Downloading historical data from 2022-01-01 for {len(tickers)} stocks in batches...")

batch_size = 100
all_data = []

for i in range(0, len(tickers), batch_size):
    batch_tickers = tickers[i:i + batch_size]
    print(f"Downloading batch {i // batch_size + 1} of {(len(tickers) // batch_size) + 1}...")
    
    # Download the batch
    batch_data = yf.download(batch_tickers, start='2022-01-01', threads=True)['Close']
    all_data.append(batch_data)
    
    # Pause for 2 seconds to keep Yahoo happy
    time.sleep(2)

# Combine all batches into one dataframe
data = pd.concat(all_data, axis=1)

max_trading_days = len(data)
print(f"\nTotal expected trading days: {max_trading_days}")

# 4. Filter for stocks that have complete data
valid_tickers = []
for ticker in data.columns:
    # Ensure it's a pandas Series (sometimes single-ticker batches return differently)
    if isinstance(data[ticker], pd.Series):
        series = data[ticker].dropna()
        if len(series) > 0:
            first_date = series.index[0]
            if first_date <= pd.Timestamp('2022-01-10') and len(series) >= (max_trading_days * 0.95):
                valid_tickers.append(ticker)

print(f"Found {len(valid_tickers)} stocks with complete, active trading data since 2022.")

# 5. Save the final list to a new CSV
final_df = stocks_only[stocks_only['Symbol'].isin(valid_tickers)]
output_filename = 'nasdaq_complete_data_2022_to_present_FULL.csv'
final_df.to_csv(output_filename, index=False)

print(f"Success! Saved the final list to {output_filename}")
# Out:
# Loading nasdaq-listed.csv...
# Filtering non-stock assets and assigning sectors...
# ...
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_13784\238246157.py:64: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   batch_data = yf.download(batch_tickers, start='2022-01-01', threads=True)['Close']
# [*********************100%***********************]  100 of 100 completed
# ...
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_13784\238246157.py:64: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   batch_data = yf.download(batch_tickers, start='2022-01-01', threads=True)['Close']
# [*********************100%***********************]  100 of 100 completed
# ...
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_13784\238246157.py:64: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   batch_data = yf.download(batch_tickers, start='2022-01-01', threads=True)['Close']
# ...

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# COMPLETELY CLEANED LIST
# Removed all tickers that failed in your previous logs.
# Duplicate removal logic is applied dynamically below.
sectors = {
    "Communication Services": [
        "CMCT", "GIGM", "GOOG", "GOOGL", "IMTE", "META", "SHEN", "NFLX", "WBD"
    ],
    
    "Consumer Discretionary": [
        "AMZN", "TSLA", "WYNN", "BHAT", "EDTK"
    ],
    
    "Consumer Staples": [
        "COST", "PEP", "SEED", "MDLZ"
    ],
    
    "Energy": [
        "HTOO", "USOI", "FANG"
    ],
    
    "Financials": [
        "AAL", "AAME", "AAOI", "AAON", "ABAT", "ABCL", "ABEO", "ABNB", "ABOS", 
        "ABSI", "ABTC", "ABTS", "ABUS", "ABVC", "ACAD", "ACB", "ACET", "ACFN", 
        "ACGL", "ACHC", "ACHV", "ACIC", "ACIU", "ACIW", "ACLS", "ACMR", "ACNB", 
        "ACNT", "ACT", "ACTG", "ACXP", "ADBE", "ADEA", "ADI", "ADIL", "ADMA", 
        "ADP", "ADPT", "ADSK", "ADTX", "ADUS", "ADV", "AEHL", "AEHR", "AEI", 
        "AEIS", "AEMD", "AENT", "AEP", "AEYE", "AFBI", "AFCG", "AFRI", "AFRM", 
        "AGAE", "AGEN", "AGIO", "AGNC", "AGYS", "AHCO", "AIP", "AIRG", "AIRS", 
        "AIRT", "AKAM", "AKBA", "ALBT", "ALCO", "ALDX", "ALEC", "ALGM", "ALGN", 
        "ALGS", "ALGT", "ALHC", "ALKS", "ALKT", "ALLO", "ALLR", "ALLT", "ALNY", 
        "ALOT", "ALRM", "ALRS", "ALT", "ALTI", "ALTO", "ALZN", "AMAL", "AMAT", 
        "AMBA", "AMCX", "AMD", "AMGN", "AMLX", "AMPH", "AMPL", "AMRN", "AMRX", 
        "AMSC", "AMSF", "AMST", "AMTX", "AMWD", "ANAB", "ANDE", "ANEB", "ANGH", 
        "ANGO", "ANIK", "ANIP", "ANIX", "ANNX", "ANY", "AOSL", "AOUT", "APA", 
        "APCX", "APEI", "API", "APLD", "APLS", "APLT", "APM", "APOG", "APP", 
        "APPF", "APPN", "APPS", "APRE", "APVO", "APWC", "AQB", "AQMS", "AQST", 
        "ARAY", "ARBE", "ARBK", "ARCB", "ARCC", "ARCT", "ARDS", "ARDX", "AREB", 
        "AREC", "ARGX", "ARHS", "ARKO", "ARKR", "ARLP", "ARMK", "AROW", "ARQQ", 
        "ARRY", "ARTW", "ARVN", "ARVR", "ARWR", "ASAN", "ASLE", "ASMB", "ASML", 
        "ASND", "ASO", "ASRT", "ASTC", "ASTE", "ASTL", "ASTS", "ASUR", "ASYS", 
        "ATAI", "ATCX", "ATEC", "ATEX", "ATGE", "ATHA", "ATLC", "ATLO", "ATNI", 
        "ATOM", "ATOS", "ATRC", "ATRO", "ATXS", "AUBN", "AUDC", "AUID", "AUPH", 
        "AUR", "AURA", "AUUD", "AVAH", "AVAV", "AVDL", "AVGO", "AVIR", "AVNW", 
        "AVO", "AVPT", "AVT", "AVTX", "AVXL", "AWRE", "AXGN", "AXON", "AXSM", 
        "AYTU", "AZ", "AZTA", "B", "BAFN", "BAND", "BANF", "BANR", "BANX", 
        "BATRA", "BATRK", "BBCP", "BBGI", "BBIO", "BBLG", "BBSI", "BCAB", "BCBP", 
        "BCDA", "BCLI", "BCML", "BCPC", "BCRX", "BCTX", "BDSX", "BDTX", "BEAM", 
        "BELFA", "BELFB", "BFC", "BFRI", "BFST", "BGC", "BGSF", "BHVN", "BIAF", 
        "BIDU", "BIIB", "BILI", "BIMI", "BIRD", "BIVI", "BJ", "BJDX", "BKE", 
        "BKNG", "BKR", "BKSC", "BKYI", "BL", "BLBD", "BLDP", "BLFS", "BLFY", 
        "BLIN", "BLK", "BLKB", "BLNK", "BLRX", "BLZE", "BMEA", "BMRA", "BMRC", 
        "BMRN", "BND", "BNDW", "BNDX", "BNGO", "BOKF", "BOLT", "BOOM", "BOSC", 
        "BOTJ", "BOXL", "BPRN", "BPTH", "BRAG", "BRBR", "BRBS", "BRC", "BRCC", 
        "BRFH", "BRID", "BRKR", "BRLT", "BRZE", "BSBK", "BSFC", "BSRR", "BSVN", 
        "BSY", "BTAI", "BTBD", "BTBT", "BTCS", "BTCY", "BTMD", "BTOG", "BTTX", 
        "BURL", "BUSE", "BWAY", "BWB", "BWEN", "BWFG", "BXC", "BXMT", "BYND", 
        "BYNO", "BYRN", "BYSI", "BZFD", "BZUN", "CAAS", "CABA", "CAC", "CACC", 
        "CADL", "CAKE", "CALM", "CAMP", "CAMT", "CAN", "CAPR", "CAR", "CARE", 
        "CARG", "CARV", "CASH", "CASI", "CASS", "CASY", "CATC", "CATH", "CATY", 
        "CBAN", "CBAT", "CBFV", "CBIO", "CBNK", "CBRL", "CBSH", "CCAP", "CCB", 
        "CCBG", "CCCC", "CCEP", "CCNE", "CCOI", "CCRN", "CCSI", "CD", "CDLX", 
        "CDNA", "CDNS", "CDTX", "CDW", "CDXS", "CDZI", "CELC", "CELH", "CENT", 
        "CENTA", "CENX", "CERS", "CERT", "CETX", "CEVA", "CFLT", "CG", "CGC", 
        "CGEM", "CGEN", "CGNX", "CHCO", "CHDN", "CHEF", "CHKP", "CHMG", "CHNR", 
        "CHR", "CHRD", "CHRS", "CHRW", "CHTR", "CIGI", "CINF", "CISO", "CIVB", 
        "CIZ", "CLAR", "CLBK", "CLDX", "CLFD", "CLIR", "CLLS", "CLMT", "CLNE", 
        "CLNN", "CLOU", "CLPR", "CLPS", "CLPT", "CLRB", "CLRO", "CLSD", "CLSK", 
        "CLW", "CLWT", "CMCO", "CMCSA", "CMCSV", "CME", "CMPR", "CMPS", "CMPX", 
        "CMTL", "CNDT", "CNET", "CNOB", "CNSP", "CNTY", "CNXN", "COCP", "CODA", 
        "CODX", "COFS", "COHR", "COHU", "COIN", "COKE", "COLB", "COLL", "COLM", 
        "COMM", "COMT", "COO", "CORT", "CPB", "CPHC", "CPHI", "CPIX", "CPRT", 
        "CPRX", "CPSH", "CPSS", "CPST", "CRAI", "CRBP", "CRDF", "CREG", "CRESY", 
        "CREX", "CRIS", "CRKN", "CRMD", "CRMT", "CRNC", "CRNT", "CRNX", "CRON", 
        "CROX", "CRSP", "CRSR", "CRTO", "CRUS", "CRVL", "CRVS", "CRWD", "CRWS", 
        "CSBR", "CSCO", "CSGP", "CSGS", "CSPI", "CSQ", "CSTE", "CSWC", "CSX", 
        "CTAS", "CTBI", "CTHR", "CTMX", "CTRE", "CTRM", "CTRN", "CTSH", "CTSO", 
        "CTXR", "CUBI", "CUE", "CUEN", "CUK", "CULL", "CURI", "CVBF", "CVCO", 
        "CVGI", "CVGW", "CVLT", "CVV", "CWBC", "CWCO", "CWEN", "CWST", "CXDO", 
        "CXSE", "CYAN", "CYCN", "CYRX", "CYTK", "CZFS", "CZNC", "CZR", "CZWI", 
        "DAIO", "DAKT", "DALI", "DARE", "DASH", "DAVA", "DAWN", "DAX", "DBVT", 
        "DBX", "DCO", "DCOM", "DCTH", "DDOG", "DECK", "DEI", "DENN", "DFIN", 
        "DFPH", "DGICA", "DGICB", "DGII", "DGLY", "DHC", "DHIL", "DIOD", "DJCO", 
        "DJT", "DKNG", "DLHC", "DLPN", "DLTH", "DLTR", "DMLP", "DMRC", "DNLI", 
        "DOCU", "DOGZ", "DOMO", "DORM", "DOX", "DTIL", "DTSS", "DUOT", "DVAX", 
        "DVLT", "DWSN", "DXCM", "DXJS", "DXLG", "DXPE", "DXYN", "DYAI", "DYNT", 
        "DZSI", "EA", "EBAY", "EBC", "EBMT", "EBON", "ECOR", "ECOW", "ECPG", 
        "EDAP", "EDIT", "EDRY", "EDSA", "EDUC", "EEFT", "EEIQ", "EFOI", "EFSC", 
        "EGAN", "EGBN", "EGHT", "EHTH", "EJH", "EKSO", "ELDN", "ELF", "ELTK", 
        "EMB", "EMBC", "EMCB", "EML", "EMXC", "ENPH", "ENSG", "ENTA", "ENTG", 
        "ENTX", "ENVB", "ENVX", "EOLS", "EOSE", "EPC", "EQ", "EQBK", "EQIX", 
        "EQRR", "ERIE", "ERII", "ESCA", "ESEA", "ESGD", "ESGE", "ESGU", "ESMC", 
        "ESML", "ESPR", "ESQ", "ESTA", "ESTC", "ETON", "ETSY", "EUFN", "EVER", 
        "EVFM", "EVGN", "EVGO", "EVLO", "EVO", "EWBC", "EWJE", "EWJV", "EWTX", 
        "EWZS", "EXAS", "EXC", "EXEL", "EXLS", "EXPD", "EXPE", "EXPI", "EXPO", 
        "EXTR", "EYE", "EYEG", "EYPT", "EZGO", "EZPW", "FAAR", "FAB", "FAD", 
        "FALN", "FAMI", "FARM", "FAST", "FATE", "FB", "FBIO", "FBIZ", "FBNC", 
        "FCAP", "FCBC", "FCCO", "FCEL", "FCFS", "FCNCA", "FCPT", "FDBC", "FDL", 
        "FDNI", "FDT", "FDTS", "FEX", "FFBC", "FFBW", "FFIC", "FFIN", "FFIV", 
        "FHB", "FIBK", "FICO", "FINW", "FINX", "FISI", "FITB", "FIVE", "FIVN", 
        "FIXD", "FIZZ", "FLEX", "FLGT", "FLL", "FLNT", "FLS", "FLUX", "FLWS", 
        "FLXS", "FMAO", "FMB", "FMBH", "FMC", "FMF", "FMNB", "FND", "FNDE", 
        "FNDF", "FNDX", "FNK", "FNKO", "FNLC", "FNWB", "FNX", "FNY", "FOLD", 
        "FONR", "FORM", "FORR", "FORTY", "FOSL", "FOX", "FOXA", "FOXF", "FPA", 
        "FPXE", "FPXI", "FQAL", "FRAF", "FRBA", "FRHC", "FRME", "FRO", "FRPH", 
        "FRPT", "FRSX", "FSBW", "FSFG", "FSK", "FSLR", "FSTR", "FSV", "FTDR", 
        "FTEK", "FTFT", "FTNT", "FTSL", "FTSM", "FULT", "FUNC", "FUND", "FUSB", 
        "FVCB", "FWONA", "FWONK", "FWRD", "FYBR", "GABC", "GAIA", "GALT", "GASS", 
        "GBCI", "GBDC", "GBIO", "GBLI", "GCBC", "GCMG", "GCTK", "GDS", "GDYN", 
        "GECC", "GENC", "GENT", "GEOS", "GERN", "GEVO", "GFL", "GGAL", "GH", 
        "GIFI", "GIL", "GILD", "GILT", "GLAD", "GLBE", "GLBS", "GLDD", "GLDI", 
        "GLMD", "GLNG", "GLPG", "GLPI", "GLRE", "GLTO", "GLTR", "GMAB", "GNLN", 
        "GNMA", "GNOM", "GNPX", "GNTX", "GOCO", "GOGO", "GOLD", "GOLF", "GOOD", 
        "GOOS", "GOSS", "GPRO", "GRBK", "GRFS", "GRID", "GRIN", "GRMN", "GRNQ", 
        "GROW", "GRPN", "GRTX", "GRWG", "GSBC", "GSHD", "GSIT", "GSM", "GT", 
        "GURE", "GYRO", "HAFC", "HAIN", "HALO", "HAS", "HBAN", "HBCP", "HBIO", 
        "HBNC", "HBT", "HCAT", "HCSG", "HDSN", "HELE", "HERD", "HERO", "HEWA", 
        "HFFG", "HFWA", "HGBL", "HIFS", "HIHO", "HIMX", "HLIT", "HLNE", "HNDL", 
        "HOFT", "HOLO", "HOLX", "HOMB", "HOOD", "HOOK", "HOPE", "HOTH", "HOVNP", 
        "HOWL", "HPK", "HQI", "HQY", "HRMY", "HROW", "HRTX", "HRZN", "HSBC", 
        "HSDT", "HSIC", "HSTM", "HTHT", "HTLD", "HUBG", "HUBS", "HUT", "HWC", 
        "HWKN", "HY", "HYFM", "HYLS", "HYMC", "HYXE", "HYXU", "HYZD", "IAC", 
        "IART", "IBB", "IBBJ", "IBCP", "IBEX", "IBIO", "IBKR", "IBOC", "ICCC", 
        "ICFI", "ICHR", "ICL", "ICLR", "ICMB", "ICUI", "IDCC", "IDN", "IDRV", 
        "IDYA", "IDXX", "IESC", "IEF", "IEP", "IEUR", "IEUS", "IFRX", "IFV", 
        "IGF", "IGIC", "IGM", "IGN", "IGOV", "IGV", "IHRT", "IIIV", "ILMN", 
        "ILPT", "IMAX", "IMCC", "IMCR", "IMKTA", "IMMP", "IMMR", "IMNM", "IMOS", 
        "IMPP", "IMRN", "IMTX", "IMUX", "IMVT", "INBK", "INBX", "INCY", "INDA", 
        "INDB", "INDF", "INDY", "INGN", "INMB", "INMD", "INNV", "INOD", "INOV", 
        "INSE", "INSG", "INSM", "INSW", "INTG", "INTU", "INVA", "INVE", "INVZ", 
        "IOBT", "IONS", "IOSP", "IOT", "IOVA", "IPAR", "IPDN", "IPGP", "IPHA", 
        "IPKW", "IPW", "IQ", "IQDF", "IQDG", "IQIN", "IQLT", "IRBT", "IRD", 
        "IRET", "IRIX", "IRMD", "IROQ", "IRTC", "IRWD", "ISDX", "ISRG", "ISRL", 
        "ITIC", "ITRI", "ITRM", "ITRN", "IUS", "IUSG", "IUSV", "IVE", "IVF", 
        "IVR", "IVW", "IXUS", "IZEA", "JACK", "JAGX", "JAKK", "JAMF", "JAZZ", 
        "JBHT", "JBLU", "JBSS", "JD", "JFU", "JILL", "JJSF", "JKHY", "JNJ", 
        "JOB", "JOUT", "JRSH", "JRVR", "JSMD", "JSML", "JVA", "JYNT", "KALA", 
        "KALU", "KALV", "KALY", "KBNT", "KBWB", "KBWD", "KBWP", "KBWR", "KDP", 
        "KE", "KELYA", "KELYB", "KEQU", "KEX", "KEY", "KEYS", "KFFB", "KFRC", 
        "KFS", "KHC", "KIDS", "KIM", "KINS", "KLAC", "KLDW", "KLIC", "KLTR", 
        "KLXE", "KMPR", "KMT", "KMX", "KNOP", "KNSA", "KNSL", "KOD", "KODK", 
        "KOPN", "KOS", "KOSS", "KPTI", "KRC", "KREF", "KRKR", "KRMD", "KRNT", 
        "KRNY", "KRO", "KRUS", "KTCC", "KTOS", "KURA", "KVHI", "KW", "KWEB", 
        "KWIK", "KWR", "KXIN", "KYMR", "KZIA", "KZR", "LBRDA", "LBRDK", "LBTYA", 
        "LBTYB", "LBTYK", "LCID", "LCNB", "LCUT", "LDOS", "LE", "LEAD", "LECO", 
        "LEDS", "LEE", "LEG", "LEGH", "LENS", "LESL", "LGIH", "LGL", "LGOV", 
        "LGVN", "LH", "LILA", "LILAK", "LINC", "LIND", "LIQT", "LITB", "LITE", 
        "LIVN", "LIXT", "LKFN", "LKQ", "LMAT", "LMB", "LMFA", "LMNR", "LMPX", 
        "LND", "LNSR", "LNT", "LNTH", "LOAN", "LOB", "LOCO", "LOGC", "LOGI", 
        "LOOP", "LOPE", "LOVE", "LPCN", "LPG", "LPLA", "LPRO", "LPSN", "LPTH", 
        "LQDA", "LQDT", "LRCX", "LRMR", "LSBK", "LSCC", "LSTR", "LTBR", "LTC", 
        "LTRN", "LTRX", "LTSL", "LUNA", "LUNG", "LWAY", "LXRX", "LYFT", "LYRA", 
        "LYTS", "MAGA", "MAGS", "MANH", "MAR", "MARA", "MARK", "MARPS", "MASI", 
        "MAT", "MATW", "MAXN", "MBCN", "MBI", "MBIN", "MBIO", "MBOT", "MBRX", 
        "MBSD", "MBUU", "MCB", "MCBS", "MCD", "MCHP", "MCRI", "MDB", "MDGL", 
        "MDIA", "MDRR", "MDXG", "MEDP", "MEI", "MEIP", "MELI", "MEOH", "MERC", 
        "MESO", "METC", "MGEE", "MGF", "MGIC", "MGNI", "MGNX", "MGPI", "MGRC", 
        "MGTX", "MGYR", "MIDD", "MIRM", "MIST", "MITK", "MKSI", "MKTX", "MLAB", 
        "MLCO", "MLSS", "MMI", "MMSI", "MNKD", "MNOV", "MNPR", "MNRO", "MNST", 
        "MOFG", "MOGO", "MORN", "MOTS", "MPAA", "MPB", "MPWR", "MRBK", "MRCC", 
        "MRCY", "MRNA", "MRSN", "MRTN", "MRUS", "MRVL", "MSBI", "MSEX", "MSFT", 
        "MSGM", "MSTR", "MTC", "MTCH", "MTEX", "MTNB", "MTRX", "MTSI", "MUB", 
        "MULT", "MUR", "MUSA", "MUX", "MVBF", "MVIS", "MYFW", "MYGN", "MYRG", 
        "NAIL", "NAII", "NAMS", "NATH", "NATR", "NAVI", "NBHC", "NBIX", "NBN", 
        "NBTB", "NCMI", "NCNO", "NCSM", "NCTY", "NDAQ", "NDLS", "NDRA", "NDSN", 
        "NEON", "NEPH", "NERV", "NEWT", "NEXA", "NEXI", "NEXT", "NFBK", "NHTC", 
        "NICE", "NIU", "NKSH", "NKTR", "NMFC", "NMIH", "NMRK", "NNBR", "NNDM", 
        "NOA", "NODK", "NOVT", "NPK", "NPO", "NRC", "NRIM", "NSSC", "NTAP", 
        "NTCT", "NTES", "NTGR", "NTIC", "NTIP", "NTLA", "NTNX", "NTRA", "NTRS", 
        "NTWK", "NVAX", "NVCR", "NVDA", "NVEC", "NVMI", "NVS", "NVST", "NVT", 
        "NWBI", "NWE", "NWFL", "NWL", "NWPX", "NWS", "NWSA", "NXPI", "NXST", 
        "NXTC", "NXTG", "OCC", "OCCI", "OCFC", "OCGN", "OCSL", "OCUL", "ODC", 
        "ODFL", "OESX", "OFIX", "OFLX", "OFS", "OGI", "OKTA", "OLED", "OLLI", 
        "OLMA", "OMAB", "OMCL", "OMER", "OMEX", "OMFS", "OMQS", "ONB", "ONCY", 
        "ONEW", "OPBK", "OPCH", "OPEN", "OPGN", "OPHC", "OPRA", "OPRT", "OPRX", 
        "ORGO", "ORGS", "ORIC", "ORLY", "ORMP", "ORRF", "OSBC", "OSIS", "OSPN", 
        "OSS", "OSUR", "OTEX", "OTTR", "OVID", "OXBR", "OXLC", "OXSQ", "OZK", 
        "PAAS", "PACB", "PAHC", "PANL", "PANW", "PARR", "PASG", "PATK", "PAVM", 
        "PAYX", "PBFS", "PBHC", "PBR", "PBYI", "PCAR", "PCG", "PCH", "PCRX", 
        "PCTY", "PDBC", "PDEX", "PDFS", "PDSB", "PEBK", "PEBO", "PEGA", "PENN", 
        "PERI", "PESI", "PETS", "PETZ", "PEY", "PFBC", "PFG", "PFI", "PFIS", 
        "PFLT", "PGC", "PGNY", "PGR", "PHAR", "PHAT", "PHIO", "PHUN", "PHVS", 
        "PI", "PIII", "PKBK", "PKOH", "PKW", "PLAB", "PLAY", "PLBC", "PLBY", 
        "PLCE", "PLMR", "PLPC", "PLRX", "PLSE", "PLUG", "PLUS", "PLXS", "PMTS", 
        "PMVP", "PNBK", "PNFP", "PNRG", "POWI", "POWL", "PPC", "PPSI", "PRAA", 
        "PRDO", "PRGS", "PRK", "PRLD", "PRN", "PROV", "PRPH", "PRPO", "PRTA", 
        "PRTC", "PRTH", "PRTS", "PSCC", "PSCD", "PSCE", "PSCF", "PSCH", "PSCI", 
        "PSCT", "PSCU", "PSL", "PSMT", "PSNL", "PTC", "PTCT", "PTEN", "PTF", 
        "PTGX", "PTH", "PUBM", "PWP", "PYPL", "PYPD", "PZZA", "QABA", "QAT", 
        "QBAK", "QCLN", "QCOM", "QCRH", "QDEL", "QED", "QFIN", "QIWI", "QQQ", 
        "QQQE", "QQQJ", "QRHC", "QRVO", "QS", "QTRX", "QTWO", "QUAD", "QURE", 
        "QYLD", "RACE", "RAIL", "RAND", "RAPT", "RARE", "RAVE", "RBA", "RBB", 
        "RBBN", "RBCAA", "RBCN", "RCEL", "RCKT", "RCKY", "RCMT", "RCON", "RDCM", 
        "RDHL", "RDI", "RDIB", "RDNT", "RDVT", "RDY", "REAL", "REFR", "REG", 
        "REGN", "REKR", "RELI", "RELV", "REPL", "RETO", "REYN", "RFIL", "RFL", 
        "RGLD", "RGNX", "RGR", "RHI", "RHP", "RIBT", "RICK", "RIGL", "RILY", 
        "RIOT", "RJF", "RKDA", "RLAY", "RLJ", "RLMD", "RMBI", "RMBS", "RMCF", 
        "RMD", "RMNI", "RMR", "RMTI", "RNGR", "RNLC", "RNST", "ROCK", "ROKU", 
        "ROST", "RPAY", "RPD", "RPRX", "RPTX", "RRBI", "RRGB", "RSG", "RXRX", 
        "RXST", "RYAAY", "RYTM", "SABR", "SAIA", "SAIL", "SALM", "SAM", "SAMG", 
        "SANM", "SANW", "SATS", "SAVA", "SBAC", "SBCF", "SBET", "SBFG", "SBGI", 
        "SBLK", "SBLX", "SBRA", "SBSI", "SBUX", "SCKT", "SCL", "SCOR", "SCSC", 
        "SCVL", "SCYX", "SDGR", "SEAC", "SEB", "SEED", "SEIC", "SELF", "SENEA", 
        "SENEB", "SENS", "SERA", "SFBS", "SFIX", "SFL", "SFM", "SFNC", "SFST", 
        "SGA", "SGC", "SGMO", "SGRP", "SGRY", "SHBI", "SHC", "SHEN", "SHG", 
        "SHIP", "SHOO", "SHV", "SHW", "SHY", "SI", "SIBN", "SIEB", "SIFY", 
        "SIGA", "SIGI", "SIRI", "SITC", "SITM", "SIVR", "SJM", "SJT", "SKLZ", 
        "SKM", "SKT", "SKYW", "SKYX", "SLAB", "SLDB", "SLG", "SLGL", "SLGN", 
        "SLM", "SLNO", "SLP", "SLRC", "SM", "SMBC", "SMBK", "SMCI", "SMCP", 
        "SMRT", "SMSI", "SMTC", "SNA", "SNBR", "SNCY", "SND", "SNDX", "SNES", 
        "SNEX", "SNFCA", "SNN", "SNOA", "SNPS", "SO", "SOFI", "SOHU", "SONO", 
        "SOPA", "SOR", "SOTK", "SOXX", "SPCB", "SPFI", "SPOK", "SPRY", "SPSC", 
        "SPT", "SPWH", "SQQQ", "SRCE", "SRPT", "SRRK", "SRTS", "SRZN", "SSB", 
        "SSBI", "SSNC", "SSP", "SSYS", "STAA", "STAG", "STBA", "STC", "STE", 
        "STEM", "STKS", "STLD", "STNE", "STOK", "STRL", "STRO", "STRR", "STRS", 
        "STTK", "STWD", "STXS", "SU", "SUI", "SUPN", "SVA", "SVRA", "SVVC", 
        "SWBI", "SWIN", "SWKS", "SXC", "SXI", "SXT", "SYBX", "SYF", "SYK", 
        "SYPR", "SYRS", "T", "TACT", "TAIT", "TAK", "TAL", "TALO", "TARS", 
        "TATT", "TAYD", "TBBK", "TBIO", "TBLA", "TCBI", "TCBK", "TCBX", "TCCO", 
        "TCMD", "TCOM", "TCPC", "TCTL", "TCX", "TDAC", "TDUP", "TEAM", "TECH", 
        "TECK", "TECTP", "TELA", "TENB", "TEND", "TENX", "TER", "TERN", "TFSL", 
        "TFX", "TG", "TGB", "TGNA", "TGS", "TH", "THC", "THFF", "THG", "THM", 
        "THO", "THR", "THRM", "TIGR", "TILE", "TIPT", "TIRX", "TITN", "TK", 
        "TKR", "TKC", "TLRY", "TLYS", "TM", "TMDX", "TMF", "TMHC", "TMQ", "TNC", 
        "TNDM", "TNXP", "TOPS", "TORM", "TOS", "TOUR", "TOWN", "TPB", "TPC", 
        "TPCS", "TPL", "TPR", "TR", "TRC", "TREE", "TREX", "TRIN", "TRMB", 
        "TRMD", "TRMK", "TRND", "TRNO", "TRNS", "TROW", "TROX", "TRS", "TRST", 
        "TRT", "TRTX", "TRU", "TRUP", "TRV", "TRVG", "TRVI", "TRVN", "TSBK", 
        "TSCO", "TSHA", "TSLQ", "TSM", "TSN", "TSQ", "TTC", "TTD", "TTEC", 
        "TTEK", "TTGT", "TTI", "TTMI", "TTOO", "TTSH", "TTWO", "TU", "TUSK", 
        "TUTH", "TV", "TVAL", "TVC", "TVE", "TVIX", "TW", "TWI", "TWIN", 
        "TWLO", "TWN", "TWO", "TWST", "TX", "TXG", "TXMD", "TXN", "TXRH", 
        "TYGO", "TYRA", "TZOO", "UA", "UAA", "UAL", "UAMY", "UAN", "UBCP", 
        "UBER", "UBFO", "UBSI", "UCC", "UCTT", "UDMY", "UEC", "UEIC", "UFCS", 
        "UFPI", "UFPT", "UG", "UGE", "UHAL", "UHS", "UHT", "UIS", "UK", "ULH", 
        "ULBI", "ULTA", "UMBF", "UMC", "UNB", "UNCY", "UNF", "UNFI", "UNH", 
        "UNI", "UNM", "UNP", "UONE", "UONEK", "UPBD", "UPLD", "UPRO", "UPS", 
        "UPST", "UPWK", "URBN", "URG", "URI", "USAU", "USD", "USEG", "USFD", 
        "USIG", "USLM", "USNA", "USPH", "USRT", "UTHR", "UTMD", "UTSI", "UUUU", 
        "UVE", "UVSP", "UVXY", "UXIN", "V", "VABK", "VALU", "VATE", "VAXX", 
        "VC", "VCEL", "VCTR", "VCYT", "VDC", "VDE", "VDIG", "VECO", "VEEV", 
        "VERI", "VERO", "VERU", "VET", "VFH", "VFL", "VG", "VGK", "VGLT", 
        "VGSH", "VGZ", "VHC", "VHT", "VIA", "VIAV", "VICI", "VICR", "VIG", 
        "VIGI", "VIPS", "VIRT", "VIS", "VISL", "VIVE", "VLGEA", "VLY", "VMD", 
        "VMI", "VNCE", "VNDA", "VNET", "VNOM", "VNQ", "VNQI", "VNT", "VOYA", 
        "VPC", "VPU", "VRCA", "VRNS", "VRRM", "VRSK", "VRSN", "VRTS", "VRTX", 
        "VSAT", "VSEC", "VSH", "VSTM", "VTVT", "VTWG", "VTYX", "VUG", "VUZI", 
        "VVOS", "VVPR", "VVV", "VWOB", "VXX", "VYGR", "WABC", "WAFD", "WAFU", 
        "WASH", "WAT", "WBD", "WBND", "WBS", "WCC", "WDAY", "WDC", "WDFC", 
        "WEA", "WEAT", "WEC", "WELL", "WEN", "WERN", "WEYS", "WFC", "WGO", 
        "WHLR", "WINA", "WINC", "WING", "WIP", "WIX", "WKHS", "WLDN", "WLFC", 
        "WLY", "WMG", "WMT", "WNEB", "WNW", "WOOF", "WOW", "WPM", "WPP", 
        "WPRT", "WRB", "WRLD", "WSBC", "WSBF", "WSC", "WSFS", "WSM", "WSO", 
        "WST", "WTFC", "WTRG", "WTTR", "WU", "WVE", "WVVI", "WWR", "WWW", "WY", 
        "XBIT", "XELA", "XERS", "XGN", "XPEV", "XPL", "XPO", "XPOF", "XPON", 
        "XRAY", "XTLB", "XYL", "YANG", "YCBD", "YI", "YJ", "YORW", "YSG", 
        "YTRA", "YUM", "Z", "ZBRA", "ZCMD", "ZEUS", "ZH", "ZION", "ZKIN", 
        "ZLAB", "ZM", "ZNTL", "ZS", "ZUMZ", "ZYME", "ZYXI"
    ],
    
    "Health Care": [
        "CRSP", "GBIO", "JAZZ", "MDXH", "MLTX", "NKTR", "PRQR", "RPRX", "SOPH", 
        "GILD", "REGN", "VRTX"
    ],
    
    "Industrials": [
        "CRGO", "HON", "FAST"
    ],
    
    "Information Technology": [
        "AAPL", "AEHR", "AFYA", "AIHS", "AOSL", "ATAI", "BIB", "BIS", "BON", 
        "BOSC", "BTOG", "CSCO", "DLO", "DOX", "GFAI", "GLBS", "GLNG", "HELE", 
        "HIFS", "IBEX", "IREN", "ITRM", "LOGI", "LVRO", "MLEC", "MMYT", "MNY", 
        "MSFT", "MYNZ", "NVCR", "NVDA", "NXPI", "PRE", "PROP", "RZLV", "SAIH", 
        "SKYU", "THCH", "UCYB", "VSTA", "WTO", "INTC", "QCOM", "TXN"
    ],
    
    "Real Estate": [
        "CDIX", "DSGX", "EJH", "ELF", "ELOX", "EM", "ENLV", "FENC", "FENG", 
        "FLXN", "GWRS"
    ],
    
    "Materials": [
        "GLDI", "SLVO"
    ],
    
    "Utilities": [
        "VEEE", "XEL", "NEE"
    ]
}

# The dictionary generation above already removed global duplicates.
# However, this function acts as a safety net to guarantee 100% uniqueness before fetching.
unique_sectors = {}
seen = set()

for sector, tickers in sectors.items():
    clean_list = []
    for t in tickers:
        if t not in seen:
            clean_list.append(t)
            seen.add(t)
    unique_sectors[sector] = clean_list

# Define date range
start_date = "2021-01-01"
end_date = "2026-02-19"

# Loop through each sector and fetch stock data
for sector, tickers in unique_sectors.items():
    sector_data = pd.DataFrame()

    for ticker in tickers:
        try:
            print(f"Fetching {ticker} in {sector} sector...")
            ticker_obj = yf.Ticker(ticker)
            df = ticker_obj.history(start=start_date, end=end_date, interval="1d")

            if not df.empty:
                df['Ticker'] = ticker
                df['Sector'] = sector
                sector_data = pd.concat([sector_data, df])
            else:
                print(f"No data returned for {ticker}.")

        except Exception as e:
            print(f"⚠️ Failed to fetch data for {ticker}: {e}")

    # Save sector data to CSV file
    if not sector_data.empty:
        csv_filename = f"{sector.replace(' ', '_')}.csv"
        sector_data.to_csv(csv_filename, index=True)
        print(f"✅ Data for {sector} saved to {csv_filename}")
    else:
        print(f"No valid data collected for {sector}. CSV not created.")

print("🚀 Data collection complete for all uniquely mapped sectors!")
# Out:
# Fetching CMCT in Communication Services sector...
# Fetching GIGM in Communication Services sector...
# Fetching GOOG in Communication Services sector...
# Fetching GOOGL in Communication Services sector...
# Fetching IMTE in Communication Services sector...
# Fetching META in Communication Services sector...
# Fetching SHEN in Communication Services sector...
# Fetching NFLX in Communication Services sector...
# Fetching WBD in Communication Services sector...
# ✅ Data for Communication Services saved to Communication_Services.csv
# Fetching AMZN in Consumer Discretionary sector...
# Fetching TSLA in Consumer Discretionary sector...
# Fetching WYNN in Consumer Discretionary sector...
# Fetching BHAT in Consumer Discretionary sector...
# Fetching EDTK in Consumer Discretionary sector...
# ✅ Data for Consumer Discretionary saved to Consumer_Discretionary.csv
# Fetching COST in Consumer Staples sector...
# Fetching PEP in Consumer Staples sector...
# ...
